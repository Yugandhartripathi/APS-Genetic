# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('GAdataFromgForm.csv')

# %%
df.head()
# Out:
#             Timestamp  Eid            Name  SQ1   SQ2  SQ3  SQ  EQ1  EQ2  EQ3  \
# 0  4/11/2019 21:56:43    1     Utsav Gupta     3    4    0  50    7    3    3
# 1  4/11/2019 21:57:37    2  Soumya Agarwal     7    4    7  65    4    3    6
# 2  4/11/2019 22:05:32    3      Rajat Garg     7    4    4  62    4    3    3
# 3  4/11/2019 22:15:16    4           Mansi     7    4    7  65   10    7    3
# 4  4/11/2019 22:18:33    5         Prateek     7    4    4  62    4    7    6
#
#            ...            C/C++  PHP  Javascript  MySQL  Java  Python  \
# 0          ...                3    2           2      3     0       0
# 1          ...                4    2           2      4     0       0
# 2          ...                3    2           1      3     0       1
# 3          ...                3    2           2      3     0       1
# 4          ...                3    1           1      1     0       3
#
# ...

# %%
df.drop('Timestamp',inplace=True,axis=1)

# %%
AOI=df['Areas of Interests']

# %%
df['Interest_WebDev']=np.zeros(shape=(df.shape[0],),dtype=int)
df['Interest_Android/IOS']=np.zeros(shape=(df.shape[0],),dtype=int)
df['Interest_GameDev']=np.zeros(shape=(df.shape[0],),dtype=int)
df['Interest_ML']=np.zeros(shape=(df.shape[0],),dtype=int)
df['Interest_Security']=np.zeros(shape=(df.shape[0],),dtype=int)
df['Interest_IoT']=np.zeros(shape=(df.shape[0],),dtype=int)

# %%
AOI[0]
# Out:
# 'Web Development Android Development Machine Learning'

# %%
for i in range(AOI.shape[0]):
    interests=AOI[i]
    interest=interests.split(' ')
    for x in interest:
        if x=='Web':
            df['Interest_WebDev'][i]=1
        elif x=='Android':
            df['Interest_Android/IOS'][i]=1
        elif x=='Game':
            df['Interest_GameDev'][i]=1
        elif x=='Machine':
            df['Interest_ML'][i]=1
        elif x=='Cyber':
            df['Interest_Security'][i]=1
        elif x=='Internet':
            df['Interest_IoT'][i]=1
# Out:
# /home/yugandhar/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/yugandhar/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/yugandhar/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# ...

# %%
df.drop('Areas of Interests',axis=1,inplace=True)

# %%
df.head()
# Out:
#    Eid            Name  SQ1   SQ2  SQ3  SQ  EQ1  EQ2  EQ3  EQ      ...       \
# 0    1     Utsav Gupta     3    4    0  50    7    3    3  70      ...
# 1    2  Soumya Agarwal     7    4    7  65    4    3    6  64      ...
# 2    3      Rajat Garg     7    4    4  62    4    3    3  61      ...
# 3    4           Mansi     7    4    7  65   10    7    3  87      ...
# 4    5         Prateek     7    4    4  62    4    7    6  72      ...
#
#    Python  HTML/CSS  Preferred OS   Preferred Text Editor  Interest_WebDev  \
# 0       0         2        Windows                Wordpad                1
# 1       0         2        Windows                Notepad                0
# 2       1         1  Linux distros                 VScode                1
# 3       1         2        Windows                    Vim                1
# 4       3         2        Windows                    Vim                0
#
#    Interest_Android/IOS  Interest_GameDev  Interest_ML  Interest_Security  \
# ...

# %%
textEditors=pd.get_dummies(df['Preferred Text Editor'],prefix='PrefTE',prefix_sep='_')

# %%
OS=pd.get_dummies(df['Preferred OS '],prefix='PrefOS',prefix_sep='_')

# %%
df=pd.concat([df,textEditors,OS],axis=1)

# %%
df.drop(['Preferred OS ','Preferred Text Editor'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Eid', 'Name', 'SQ1 ', 'SQ2', 'SQ3', 'SQ', 'EQ1', 'EQ2', 'EQ3', 'EQ',
#        'IQ1', 'IQ2', 'IQ3', 'IQ', 'C/C++', 'PHP', 'Javascript', 'MySQL',
#        'Java', 'Python', 'HTML/CSS', 'Interest_WebDev', 'Interest_Android/IOS',
#        'Interest_GameDev', 'Interest_ML', 'Interest_Security', 'Interest_IoT',
#        'PrefTE_Atom', 'PrefTE_Brackets', 'PrefTE_Eclipse', 'PrefTE_Emacs',
#        'PrefTE_Notepad', 'PrefTE_Sublime', 'PrefTE_VScode', 'PrefTE_Vim',
#        'PrefTE_Wordpad', 'PrefTE_codechef', 'PrefOS_Linux distros',
#        'PrefOS_Windows'],
#       dtype='object')

# %%
for i in range(df.shape[0]):
    temp=[]
    temp=(df['Name'][i].split(' '))
    df['Name'][i]=temp.join();
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-d1f7965cadf3> in <module>
#       2     temp=[]
#       3     temp=(df['Name'][i].split(' '))
# ----> 4     df['Name'][i]=temp.join();
#
# AttributeError: 'list' object has no attribute 'join'

# %%
df.to_csv('processedData',index=False)
